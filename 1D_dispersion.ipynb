# %% [markdown]
# <a href="https://colab.research.google.com/github/gibeom92/dispersion_PINN/blob/master/1D_dispersion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  # %tensorflow_version 2.x
except Exception:
  pass

# !pip install --upgrade pyDOE
# Out:
# Collecting pyDOE
#   Downloading https://files.pythonhosted.org/packages/bc/ac/91fe4c039e2744466621343d3b8af4a485193ed0aab53af5b1db03be0989/pyDOE-0.3.8.zip
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.6/dist-packages (from pyDOE) (1.19.5)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.6/dist-packages (from pyDOE) (1.4.1)
# Building wheels for collected packages: pyDOE
#   Building wheel for pyDOE (setup.py) ... done
#   Created wheel for pyDOE: filename=pyDOE-0.3.8-cp36-none-any.whl size=18178 sha256=44564148ad23dbb8c024a3b0fe6c4c3188bbc40cd858c5cb1da6b1371ed3c643
#   Stored in directory: /root/.cache/pip/wheels/7c/c8/58/a6493bd415e8ba5735082b5e0c096d7c1f2933077a8ce34544
# Successfully built pyDOE
# Installing collected packages: pyDOE
# Successfully installed pyDOE-0.3.8

# %%
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
from pyDOE import lhs
from scipy.interpolate import griddata
import time

np.random.seed(1234)
tf.random.set_seed(1234)

# %%
N_C = 10000   # No. of Optimization input (B.C, I.C) 
N_f = 30000   # No. of Optimization input (f function)
layers = [2, 64,64,64,64,64,64,64,64,64, 1]   # NN config/ 2 input, 1 output
wind = 5    # u
K = 5

# %%
# Training input

x = np.arange(-10.0, 10.0, 0.0001)
t = np.arange(0, 0.1, 0.0001)
X, T = np.meshgrid(x, t)

C_0 = 1 / np.cosh(10*x)   # initial condition

X_star = np.hstack((X.flatten()[:,None], T.flatten()[:,None]))
lb = X_star.min(0); ub = X_star.max(0)
C_star = C_0.flatten()[:,None]

# Optimization input (f function)
# I.C
xx1 = np.hstack((X[0:1, :].T, T[0:1, :].T))
CC1 = C_0.flatten()[:,None]
# B.C 1
xx2 = np.hstack((X[:, 0:1], T[:, 0:1]))
xx2[:,0] = -8
CC2 = (np.random.uniform(size=len(t)) * 1.0e-100).flatten()[:,None]
# B.C 2
xx3 = np.hstack((X[:, -1:], T[:, -1:]))
xx3[:,0] = 8
CC3 = (np.random.uniform(size=len(t)) * 1.0e-100).flatten()[:,None]

X_C_train = np.vstack([xx1, xx2, xx3])
X_f_train = lb + (ub - lb) * lhs(2, N_f)    # Optimization input (f function)
X_f_train = np.vstack((X_f_train, X_C_train))
C_train = np.vstack([CC1, CC2, CC3])

idx = np.random.choice(X_C_train.shape[0], N_C, replace=False)
X_C_train = X_C_train[idx, :]
C_train = C_train[idx, :]

# %%
class PINN:
  def __init__(self, X_C, C, X_f, layers, lb, ub, wind, K):

    self.dtype = tf.float32
    self.count = 0

    self.x_C = tf.convert_to_tensor(X_C[:,0:1], dtype=self.dtype)
    self.t_C = tf.convert_to_tensor(X_C[:,1:2], dtype=self.dtype)

    self.x_f = tf.convert_to_tensor(X_f[:,0:1], dtype=self.dtype)   # (n, 1) shape으로 나옴
    self.t_f = tf.convert_to_tensor(X_f[:,1:2], dtype=self.dtype)

    self.C = tf.convert_to_tensor(C, dtype=self.dtype) 

    self.sizes_w = []
    self.sizes_b = []
    for i, width in enumerate(layers):
      if i != 1:
        self.sizes_w.append(int(width * layers[1]))
        self.sizes_b.append(int(width if i != 0 else layers[1]))

    # neural network
    self.C_model = tf.keras.Sequential()
    self.C_model.add(tf.keras.layers.InputLayer(input_shape=(layers[0],)))
    self.C_model.add(tf.keras.layers.Lambda(lambda X: 2.0 * (X - lb)/(ub - lb) - 1.0))
    for node in layers[1:-2]:
      self.C_model.add(tf.keras.layers.Dense(node, activation = 'tanh', 
                                             kernel_initializer = 'glorot_normal'))  # glorot: xavier initializer
    for node in layers[-2:]:
      self.C_model.add(tf.keras.layers.Dense(node, activation = 'sigmoid', 
                                             kernel_initializer = 'glorot_normal', 
                                             bias_constraint = tf.keras.constraints.NonNeg()))

  # network for C / C_pred / C_0 와 비교
  def net_C(self):
    X_C = tf.stack([self.x_C, self.t_C], axis=1)
    C = self.C_model(X_C)
    return C

  # Calculate f / PDE
  def net_f(self):
    with tf.GradientTape(persistent = True) as tape:   # persistent = False
      tape.watch(self.x_f)
      tape.watch(self.t_f)
      X_f = tf.stack([self.x_f, self.t_f], axis=1)
      
      C = self.C_model(X_f)
      C_t = tape.gradient(C, self.t_f)
      C_x = tape.gradient(C, self.x_f)
      C_xx = tape.gradient(C_x, self.x_f)

    del tape
    return C_t + wind * C_x - K * C_xx

  # Loss
  @tf.function    # get_weight, set_weight 가 tf.function 에서 안됨
  def loss(self):
    f_pred = self.net_f()
    C_pred = self.net_C()
    return tf.reduce_mean(tf.square(self.C - C_pred)) + tf.reduce_mean(tf.square(f_pred))

  def get_weights(self):
    w = []
    for layer in self.C_model.layers[1:]:
      weights_biases = layer.get_weights()
      weights = weights_biases[0].flatten()
      biases = weights_biases[1]
      w.extend(weights)
      w.extend(biases)
    return tf.convert_to_tensor(w, dtype=self.dtype)

  def set_weights(self, w):   # weight update를 위한 함수
    for i, layer in enumerate(self.C_model.layers[1:]):
      start_weights = sum(self.sizes_w[:i]) + sum(self.sizes_b[:i])
      end_weights = sum(self.sizes_w[:i+1]) + sum(self.sizes_b[:i])
      weights = w[start_weights:end_weights]
      w_div = int(self.sizes_w[i] / self.sizes_b[i])
      weights = tf.reshape(weights, [w_div, self.sizes_b[i]])
      biases = w[end_weights:end_weights + self.sizes_b[i]]
      weights_biases = [weights, biases]
      layer.set_weights(weights_biases)

  def step(self):
    self.count += 1
    return self.count

  def train(self):
    def optim(w):
      with tf.GradientTape() as tape:
        self.set_weights(w)
        loss = self.loss()
      grad = tape.gradient(loss, self.C_model.trainable_variables)
      grad_flat = []
      for g in grad:
        grad_flat.append(tf.reshape(g, [-1]))
      grad_flat = tf.concat(grad_flat, 0)
      self.step()
      if self.count % 100 == 0:
        print(self.count, ': ', loss)
      return loss, grad_flat

    return tfp.optimizer.lbfgs_minimize(
        optim, self.get_weights(),
        num_correction_pairs = 50, 
        max_iterations = 5000, 
        parallel_iterations = 256)

# %%
# Training

model = PINN(X_C_train, C_train, X_f_train, layers, lb, ub, wind, K)

with tf.device('/gpu:0'):
  start_time = time.time()
  result = model.train()    # training
  elapsed = time.time() - start_time
  print('time: ', elapsed)
# Out:
# 100 :  tf.Tensor(0.00855105, shape=(), dtype=float32)
# 200 :  tf.Tensor(0.008392417, shape=(), dtype=float32)
# 300 :  tf.Tensor(0.005198696, shape=(), dtype=float32)
# 400 :  tf.Tensor(0.0043112068, shape=(), dtype=float32)
# 500 :  tf.Tensor(0.004069152, shape=(), dtype=float32)
# 600 :  tf.Tensor(0.003446476, shape=(), dtype=float32)
# 700 :  tf.Tensor(0.0030208007, shape=(), dtype=float32)
# 800 :  tf.Tensor(0.0028675757, shape=(), dtype=float32)
# 900 :  tf.Tensor(0.0025233508, shape=(), dtype=float32)
# 1000 :  tf.Tensor(0.0024409452, shape=(), dtype=float32)
# 1100 :  tf.Tensor(0.0022744439, shape=(), dtype=float32)
# 1200 :  tf.Tensor(0.0021884588, shape=(), dtype=float32)
# 1300 :  tf.Tensor(0.0020944197, shape=(), dtype=float32)
# 1400 :  tf.Tensor(0.002013284, shape=(), dtype=float32)
# 1500 :  tf.Tensor(0.0020061117, shape=(), dtype=float32)
# 1600 :  tf.Tensor(0.0018598472, shape=(), dtype=float32)
# 1700 :  tf.Tensor(0.0018295862, shape=(), dtype=float32)
# 1800 :  tf.Tensor(0.0017662696, shape=(), dtype=float32)
# 1900 :  tf.Tensor(0.0017120161, shape=(), dtype=float32)
# 2000 :  tf.Tensor(0.0016247425, shape=(), dtype=float32)
# 2100 :  tf.Tensor(0.0015898561, shape=(), dtype=float32)
# 2200 :  tf.Tensor(0.0015505645, shape=(), dtype=float32)
# 2300 :  tf.Tensor(0.0015312717, shape=(), dtype=float32)
# 2400 :  tf.Tensor(0.0014558259, shape=(), dtype=float32)
# 2500 :  tf.Tensor(0.0013807723, shape=(), dtype=float32)
# 2600 :  tf.Tensor(0.0013461495, shape=(), dtype=float32)
# 2700 :  tf.Tensor(0.0012564573, shape=(), dtype=float32)
# 2800 :  tf.Tensor(0.0011862752, shape=(), dtype=float32)
# 2900 :  tf.Tensor(0.0011568179, shape=(), dtype=float32)
# 3000 :  tf.Tensor(0.0011370479, shape=(), dtype=float32)
# 3100 :  tf.Tensor(0.0011093694, shape=(), dtype=float32)
# 3200 :  tf.Tensor(0.0010491782, shape=(), dtype=float32)
# 3300 :  tf.Tensor(0.0010267184, shape=(), dtype=float32)
# 3400 :  tf.Tensor(0.0009737038, shape=(), dtype=float32)
# 3500 :  tf.Tensor(0.0009557244, shape=(), dtype=float32)
# 3600 :  tf.Tensor(0.00093061215, shape=(), dtype=float32)
# 3700 :  tf.Tensor(0.00092393346, shape=(), dtype=float32)
# 3800 :  tf.Tensor(0.0008984098, shape=(), dtype=float32)
# 3900 :  tf.Tensor(0.0008351749, shape=(), dtype=float32)
# 4000 :  tf.Tensor(0.0008300317, shape=(), dtype=float32)
# 4100 :  tf.Tensor(0.0008115466, shape=(), dtype=float32)
# 4200 :  tf.Tensor(0.0008269439, shape=(), dtype=float32)
# 4300 :  tf.Tensor(0.00072685035, shape=(), dtype=float32)
# 4400 :  tf.Tensor(0.00071408495, shape=(), dtype=float32)
# 4500 :  tf.Tensor(0.00070881785, shape=(), dtype=float32)
# 4600 :  tf.Tensor(0.0006828141, shape=(), dtype=float32)
# 4700 :  tf.Tensor(0.0006714747, shape=(), dtype=float32)
# 4800 :  tf.Tensor(0.0006359507, shape=(), dtype=float32)
# 4900 :  tf.Tensor(0.00061482715, shape=(), dtype=float32)
# 5000 :  tf.Tensor(0.0005979936, shape=(), dtype=float32)
# 5100 :  tf.Tensor(0.00058229, shape=(), dtype=float32)
# 5200 :  tf.Tensor(0.0005644377, shape=(), dtype=float32)
# 5300 :  tf.Tensor(0.00055316975, shape=(), dtype=float32)
# 5400 :  tf.Tensor(0.0005422289, shape=(), dtype=float32)
# 5500 :  tf.Tensor(0.00053511246, shape=(), dtype=float32)
# 5600 :  tf.Tensor(0.00052862987, shape=(), dtype=float32)
# 5700 :  tf.Tensor(0.0004991949, shape=(), dtype=float32)
# 5800 :  tf.Tensor(0.0004842232, shape=(), dtype=float32)
# 5900 :  tf.Tensor(0.0004748506, shape=(), dtype=float32)
# 6000 :  tf.Tensor(0.0004708205, shape=(), dtype=float32)
# 6100 :  tf.Tensor(0.00046921743, shape=(), dtype=float32)
# 6200 :  tf.Tensor(0.0004624602, shape=(), dtype=float32)
# 6300 :  tf.Tensor(0.00044167368, shape=(), dtype=float32)
# 6400 :  tf.Tensor(0.00043519266, shape=(), dtype=float32)
# 6500 :  tf.Tensor(0.0004343948, shape=(), dtype=float32)
# 6600 :  tf.Tensor(0.0004331264, shape=(), dtype=float32)
# 6700 :  tf.Tensor(0.00042379939, shape=(), dtype=float32)
# 6800 :  tf.Tensor(0.00040572154, shape=(), dtype=float32)
# 6900 :  tf.Tensor(0.00039780102, shape=(), dtype=float32)
# 7000 :  tf.Tensor(0.00038801972, shape=(), dtype=float32)
# 7100 :  tf.Tensor(0.00038651083, shape=(), dtype=float32)
# 7200 :  tf.Tensor(0.00038238493, shape=(), dtype=float32)
# 7300 :  tf.Tensor(0.00036854472, shape=(), dtype=float32)
# 7400 :  tf.Tensor(0.00035190437, shape=(), dtype=float32)
# 7500 :  tf.Tensor(0.00035028084, shape=(), dtype=float32)
# 7600 :  tf.Tensor(0.00034849276, shape=(), dtype=float32)
# 7700 :  tf.Tensor(0.000339337, shape=(), dtype=float32)
# 7800 :  tf.Tensor(0.00032415328, shape=(), dtype=float32)
# 7900 :  tf.Tensor(0.0003111229, shape=(), dtype=float32)
# 8000 :  tf.Tensor(0.00030724966, shape=(), dtype=float32)
# 8100 :  tf.Tensor(0.00030334268, shape=(), dtype=float32)
# 8200 :  tf.Tensor(0.0003007427, shape=(), dtype=float32)
# 8300 :  tf.Tensor(0.00029911054, shape=(), dtype=float32)
# 8400 :  tf.Tensor(0.00029610645, shape=(), dtype=float32)
# 8500 :  tf.Tensor(0.0002907642, shape=(), dtype=float32)
# 8600 :  tf.Tensor(0.00028568224, shape=(), dtype=float32)
# 8700 :  tf.Tensor(0.0002823368, shape=(), dtype=float32)
# 8800 :  tf.Tensor(0.00027190917, shape=(), dtype=float32)
# 8900 :  tf.Tensor(0.00026927964, shape=(), dtype=float32)
# 9000 :  tf.Tensor(0.00026599073, shape=(), dtype=float32)
# 9100 :  tf.Tensor(0.00026343612, shape=(), dtype=float32)
# 9200 :  tf.Tensor(0.00025920817, shape=(), dtype=float32)
# 9300 :  tf.Tensor(0.0002513121, shape=(), dtype=float32)
# 9400 :  tf.Tensor(0.00024830143, shape=(), dtype=float32)
# 9500 :  tf.Tensor(0.00024063553, shape=(), dtype=float32)
# 9600 :  tf.Tensor(0.00023775236, shape=(), dtype=float32)
# 9700 :  tf.Tensor(0.00023569036, shape=(), dtype=float32)
# 9800 :  tf.Tensor(0.00023173493, shape=(), dtype=float32)
# 9900 :  tf.Tensor(0.00022683758, shape=(), dtype=float32)
# 10000 :  tf.Tensor(0.00022557715, shape=(), dtype=float32)
# 10100 :  tf.Tensor(0.00022299704, shape=(), dtype=float32)
# 10200 :  tf.Tensor(0.00022193172, shape=(), dtype=float32)
# 10300 :  tf.Tensor(0.00021961972, shape=(), dtype=float32)
# 10400 :  tf.Tensor(0.0002181606, shape=(), dtype=float32)
# 10500 :  tf.Tensor(0.000211229, shape=(), dtype=float32)
# 10600 :  tf.Tensor(0.00020961632, shape=(), dtype=float32)
# 10700 :  tf.Tensor(0.00020893515, shape=(), dtype=float32)
# 10800 :  tf.Tensor(0.0002082932, shape=(), dtype=float32)
# 10900 :  tf.Tensor(0.00020778574, shape=(), dtype=float32)
# time:  2672.278667449951

# %%
# Test

dx = 0.1
x = np.arange(-10.0, 10.0, dx)
dt = 0.01
t = np.arange(0, 0.1, dt)
X, T = np.meshgrid(x, t)

X_star = np.hstack((X.flatten()[:,None], T.flatten()[:,None]))

C_pred = model.C_model(X_star)
result = griddata(X_star, C_pred, (X, T), method='cubic')

# %%
C_0 = 1 / np.cosh(10*x)

# %%
np.shape(result[0])
# Out:
# (200, 1)

# %%
result[0] = np.reshape(C_0,(200,1))

# %%
plt.rcParams['figure.figsize'] = [12, 12]
plt.rcParams.update({'font.size': 18})
fsize = 25

# Waterfall plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_zlim3d(0, 1)

C_plot = np.reshape(result,(10,200))
for j in range(C_plot.shape[0]):
    ys = j * np.ones(C_plot.shape[1]) * dt
    ax.plot(x, ys, C_plot[j, :])
    ax.set_xlabel('x', size=fsize, labelpad=20)                                
    ax.set_ylabel('t', size=fsize, labelpad=20)                            
    ax.set_zlabel('C', size=fsize, labelpad=20)  

# Image plot
plt.figure()
#plt.imshow(np.flipud(u), aspect=8)
plt.axis('off')
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.DataFrame(C_plot)
df.to_excel(excel_writer='/content/drive/My Drive/Colab Notebooks/Dispersion/PINN2.xlsx')
